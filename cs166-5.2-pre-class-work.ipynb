# %%
import networkx as nx

# %% [markdown]
# ### Sayama 15.3

# %%
graph_1 = networkx.complete_graph(4)
nx.draw(graph_1)

# %%
graph_3 = networkx.complete_multipartite_graph(2, 3)
nx.draw(graph_3)

# %%
graph_4 = networkx.complete_multipartite_graph(3, 3)
nx.draw(graph_4)

# %% [markdown]
# ### Sayama 15.10

# %%
hycb_graph = networkx.hypercube_graph(4)
nx.draw(hycb_graph)

# %%
lad_graph = networkx.ladder_graph(5)
nx.draw(lad_graph)

# %%
barb_graph = networkx.barbell_graph(20, 0)
nx.draw(barb_graph)

# %%
whl_graph = networkx.wheel_graph(100)
nx.draw(whl_graph)
