# %%
from scipy.optimize import root
import numpy as np
import matplotlib.pyplot as plt

# %%
def calculate_q(k):
    '''
    Use a numerical root finder to determine q from the equation
    q = exp(k*(q-1)).
    '''

    return root(lambda q: q - np.exp(k * (q - 1)), 0).x[0]

def calculate_lcc_size(n=100, p=0.05, q, k):
    
    
    return num_nodes

# %%
k_range = np.arange(0, 10, 0.25)
n = 1000

plt.figure(figsize=(10, 6), dpi=330)
plt.plot(k_range, [n * (1 - calculate_q(k)) for k in k_range])
plt.xlabel('<k>')
plt.ylabel('LCC size')
plt.xticks(range(0, 10))
plt.show()
